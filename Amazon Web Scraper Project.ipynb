# %%
# import libraries 

from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
URL ='https://www.amazon.in/Nucleus-Science-T-Shirts-Tshirts-Chemistry/dp/B0B3MGHLPP/ref=sr_1_14?dib=eyJ2IjoiMSJ9.XrdLll3ukkkIJQSaZmHLLi7rKvjO1X9wvy5lUX0H2l5BbFiwPbWqt5JcpHTrT-zA-vrjYPyzQfYsBLwSKnB3XGF8ND9ph-xobILr7sdOobwKDzOrwYV4xE8BZzg2QMHbAjf95RaBxk2YhUoU61RgnBkwubKjl1GO5V3pp8dfs72qS8O15vhuMOB3lbl9KxAuPrdYmC_n2KR1i-AFLW2Osh58hijbhO5wkgD8w0dyOE4tDaQ00Sq9zkyvGBygvtaQutvCz6k0cXFHgfckbPyona4GXN-j_8hr5dl65wOmxOg.xh8qGImHYHBNKpq7ftwuFte2WDTsFyAB0i5qH3LAbYE&dib_tag=se&keywords=data%2Bscience%2Btshirt&qid=1777861919&sr=8-14&th=1&psc=1'

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36", 
    "Accept-Encoding":"gzip, deflate", 
    "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", 
    "DNT":"1",
    "Connection":"close", 
    "Upgrade-Insecure-Requests":"1"
}
page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

title = soup2.find(id = 'productTitle').get_text()

price_element = soup2.find(class_='a-price-whole')

print(title)
print(price)
# Out:
#                  Nucleus | Science T-Shirts | Science Quote Tshirts | Chemistry T-Shirt | Physics T-Shirt Printed Half Sleeve Round Neck Funny Hindi Text Graphic T Shirt/Top for Men and Women
#
# 399

# %%
price = price.strip()
title = title.strip()

print(title)
print(price)
# Out:
# Nucleus | Science T-Shirts | Science Quote Tshirts | Chemistry T-Shirt | Physics T-Shirt Printed Half Sleeve Round Neck Funny Hindi Text Graphic T Shirt/Top for Men and Women
# 399

# %%
import datetime

today = datetime.date.today()
print(today)
# Out:
# 2026-05-04

# %%
import csv

header = ['Title', 'Price','Date']
data = [title, price, today]

with open("AmazonWebScrapper.csv", "w", newline = '', encoding = 'UTF8') as f :
        writer = csv.writer(f)
        writer.writerow(header)
        writer.writerow(data)

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\Irish Gyawali\AmazonWebScrapper.csv')
print(df)
# Out:
#                                                Title  Price        Date
# 0  Nucleus | Science T-Shirts | Science Quote Tsh...    399  2026-05-04
# 1  Nucleus | Science T-Shirts | Science Quote Tsh...    399  2026-05-04
# 2  Nucleus | Science T-Shirts | Science Quote Tsh...    399  2026-05-04
# 3  Nucleus | Science T-Shirts | Science Quote Tsh...    399  2026-05-04
# 4  Nucleus | Science T-Shirts | Science Quote Tsh...    399  2026-05-04

# %%
with open('AmazonWebscrapper.csv', 'a+', newline = '', encoding = 'UTF8') as f :
         writer = csv.writer(f)
         writer.writerow(data)

# %%
def check_price():
    URL = 'https://www.amazon.in/Nucleus-Science-T-Shirts-Tshirts-Chemistry/dp/B0B3MGHLPP/'
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    page = requests.get(URL, headers=headers)
    soup1 = BeautifulSoup(page.content, "html.parser")
    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

    # This gets the element AND strips it in one line
    title_el = soup2.find(id='productTitle')
    title = title_el.get_text().strip() if title_el else "Title Not Found"

    price_el = soup2.find(class_='a-price-whole')
    price = price_el.get_text().strip() if price_el else "0"

    import datetime
    today = datetime.date.today()

    import csv
    data = [title, price, today]

    with open('AmazonWebscrapper.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

     if(price < 300):
         send_mail()

# %%
while (True):
        check_price()
        time.sleep(86400)

# %%
import pandas as pd 

df = df = pd.read_csv(r'C:\Users\Irish Gyawali\AmazonWebScrapper.csv')
print(df)
# Out:
#                                                 Title  Price        Date
# 0   Nucleus | Science T-Shirts | Science Quote Tsh...    399  2026-05-04
# 1   Nucleus | Science T-Shirts | Science Quote Tsh...    399  2026-05-04
# 2   Nucleus | Science T-Shirts | Science Quote Tsh...    399  2026-05-04
# 3   Nucleus | Science T-Shirts | Science Quote Tsh...    399  2026-05-04
# 4   Nucleus | Science T-Shirts | Science Quote Tsh...    399  2026-05-04
# 5   Nucleus | Science T-Shirts | Science Quote Tsh...    399  2026-05-04
# 6   Nucleus | Science T-Shirts | Science Quote Tsh...    399  2026-05-04
# 7   Nucleus | Science T-Shirts | Science Quote Tsh...    399  2026-05-04
# 8   Nucleus | Science T-Shirts | Science Quote Tsh...    399  2026-05-04
# 9   Nucleus | Science T-Shirts | Science Quote Tsh...    399  2026-05-04
# 10  Nucleus | Science T-Shirts | Science Quote Tsh...    399  2026-05-04
# 11  Nucleus | Science T-Shirts | Science Quote Tsh...    399  2026-05-04
# ...

# %%
def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('utsavgyawali@gmail.com','xxxxxxxxxxxxxx')
    
    subject = "The Shirt you want is below ₹300! Now is your chance to buy!"
    body = "Utsav, This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dreams. Don't mess it up! Link here:'https://www.amazon.in/Nucleus-Science-T-Shirts-Tshirts-Chemistry/dp/B0B3MGHLPP/ref=sr_1_14?dib=eyJ2IjoiMSJ9.XrdLll3ukkkIJQSaZmHLLi7rKvjO1X9wvy5lUX0H2l5BbFiwPbWqt5JcpHTrT-zA-vrjYPyzQfYsBLwSKnB3XGF8ND9ph-xobILr7sdOobwKDzOrwYV4xE8BZzg2QMHbAjf95RaBxk2YhUoU61RgnBkwubKjl1GO5V3pp8dfs72qS8O15vhuMOB3lbl9KxAuPrdYmC_n2KR1i-AFLW2Osh58hijbhO5wkgD8w0dyOE4tDaQ00Sq9zkyvGBygvtaQutvCz6k0cXFHgfckbPyona4GXN-j_8hr5dl65wOmxOg.xh8qGImHYHBNKpq7ftwuFte2WDTsFyAB0i5qH3LAbYE&dib_tag=se&keywords=data%2Bscience%2Btshirt&qid=1777861919&sr=8-14&th=1&psc=1'
 
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'AlexTheAnalyst95@gmail.com',
        msg
     
    )
